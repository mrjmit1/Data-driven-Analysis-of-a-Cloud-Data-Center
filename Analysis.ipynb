# %%
#import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np 
import os
import glob
import matplotlib

# %%
d1=pd.read_csv("\Dataset120-200.csv")
d2=pd.read_csv("\Dataset201-264.csv")
# Out:
# \ipykernel_38620\1262065519.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   d1=pd.read_csv("\Dataset120-200.csv")

# %%
d1.index = pd.to_datetime(d1['Time'], format='%Y.%m.%d %H:%M:%S')
d2.index = pd.to_datetime(d2['Time'], format='%Y.%m.%d %H:%M:%S')

# %%
d1
# Out:
#                               Unnamed: 0       Series                 Time  \
# Time
# 2018-10-09 11:20:00  2018-10-09 11:20:00  qh2-rcc120   2018-10-09 11:20:00
# 2018-10-09 11:30:00  2018-10-09 11:30:00  qh2-rcc120   2018-10-09 11:30:00
# 2018-10-09 11:40:00  2018-10-09 11:40:00  qh2-rcc120   2018-10-09 11:40:00
# 2018-10-09 11:50:00  2018-10-09 11:50:00  qh2-rcc120   2018-10-09 11:50:00
# 2018-10-09 12:00:00  2018-10-09 12:00:00  qh2-rcc120   2018-10-09 12:00:00
# ...                                  ...          ...                  ...
# 2019-05-30 11:30:00                97064   qh2-rcc200  2019-05-30 11:30:00
# 2019-05-30 11:40:00                97065   qh2-rcc200  2019-05-30 11:40:00
# 2019-05-30 11:50:00                97066   qh2-rcc200  2019-05-30 11:50:00
# 2019-05-30 12:00:00                97067   qh2-rcc200  2019-05-30 12:00:00
# 2019-05-30 12:10:00                97068   qh2-rcc200  2019-05-30 12:10:00
#
# ...

# %%
d2
# Out:
#                                     Time  Unnamed: 0      Series  \
# Time
# 2019-02-07 15:40:00  2019-02-07 15:40:00         891  qh2-rcc201
# 2019-02-07 15:50:00  2019-02-07 15:50:00         892  qh2-rcc201
# 2019-02-07 16:00:00  2019-02-07 16:00:00         893  qh2-rcc201
# 2019-02-07 16:10:00  2019-02-07 16:10:00         894  qh2-rcc201
# 2019-02-07 16:20:00  2019-02-07 16:20:00         895  qh2-rcc201
# ...                                  ...         ...         ...
# 2019-06-05 03:10:00  2019-06-05 03:10:00     1238790  qh2-rcc262
# 2019-06-05 03:20:00  2019-06-05 03:20:00     1238791  qh2-rcc262
# 2019-06-05 03:30:00  2019-06-05 03:30:00     1238792  qh2-rcc262
# 2019-06-05 03:40:00  2019-06-05 03:40:00     1238793  qh2-rcc262
# 2019-06-05 03:50:00  2019-06-05 03:50:00     1238794  qh2-rcc262
#
#                                   Time.1  CPU_Load  CPU1_Temperature  \
# Time
# 2019-02-07 15:40:00  2019-02-07 15:40:00  1.216500         49.800000
# ...

# %% [markdown]
# Probablity Distribution Function (PDF)

# %%
import matplotlib


plt.figure(figsize=(8, 6))
sns.distplot(d1.CPU_Load)
sns.distplot(d2.CPU_Load)

plt.xlabel( r"$\ CPU (\%) $", fontsize=24)
plt.ylabel(r"$\ Density $", fontsize=24)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.legend(labels = ['D1','D2'],loc='upper right', fontsize=22)
#plt.savefig("CPU_Load_PDF.pdf", format="pdf", bbox_inches="tight")
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(d1.Power)
sns.distplot(d2.Power)

plt.xlabel( r"$\ P_c(Watt) $", fontsize=24)
plt.ylabel(r"$\ Density $", fontsize=24)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.legend(labels = ['D1','D2'],loc='upper right', fontsize=22)
plt.savefig("Power_PDF.pdf", format="pdf", bbox_inches="tight")
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(d1.Network_RX)
sns.distplot(d2.Network_RX)

plt.xlabel( r"$\ N_{R_x}(Kbps) $", fontsize=24)
plt.ylabel(r"$\ Density $", fontsize=24)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.legend(labels = ['D1','D2'],loc='upper right', fontsize=22)
plt.savefig("Network_RX_PDF.pdf", format="pdf", bbox_inches="tight")
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(d1.Network_TX)
sns.distplot(d2.Network_TX)

plt.xlabel( r"$\ N_{T_x}(Kbps) $", fontsize=24)
plt.ylabel(r"$\ Density $", fontsize=24)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.legend(labels = ['D1','D2'],loc='upper right', fontsize=22)
plt.savefig("Network_TX_PDF.pdf", format="pdf", bbox_inches="tight")
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(d1.CPU1_Temperature)
sns.distplot(d2.CPU1_Temperature)

plt.xlabel( r"$\ T_{CPU_1}(°C) $", fontsize=24)
plt.ylabel(r"$\ Density $", fontsize=24)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.legend(labels = ['D1','D2'],loc='upper left', fontsize=22)
plt.savefig("CPU1_Temperature_PDF.pdf", format="pdf", bbox_inches="tight")
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(d1.CPU2_Temperature)
sns.distplot(d2.CPU2_Temperature)

plt.xlabel( r"$\ T_{CPU_2}(°C) $", fontsize=24)
plt.ylabel(r"$\ Density $", fontsize=24)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.legend(labels = ['D1','D2'],loc='upper right', fontsize=22)
plt.savefig("CPU2_Temperature_PDF.pdf", format="pdf", bbox_inches="tight")
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(d1.Ram_Used)
sns.distplot(d2.Ram_Used)

plt.xlabel( r"$\ R_x(GB) $", fontsize=24)
plt.ylabel(r"$\ Density $", fontsize=24)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.legend(labels = ['D1','D2'],loc='upper right', fontsize=22)
plt.savefig("Ram_Used_PDF.pdf", format="pdf", bbox_inches="tight")
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(d1.No_Of_Running_vms)
sns.distplot(d2.No_Of_Running_vms)

plt.xlabel( r"$\ N_{vm} $", fontsize=24)
plt.ylabel(r"$\ Density $", fontsize=24)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.legend(labels = ['D1','D2'],loc='upper right', fontsize=22)
plt.savefig("No_Of_Running_vms_PDF.pdf", format="pdf", bbox_inches="tight")
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(d1.CPU_cores_used)
sns.distplot(d2.CPU_cores_used)

plt.xlabel( r"$\ N_{CPU_x} $", fontsize=24)
plt.ylabel(r"$\ Density $", fontsize=24)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.legend(labels = ['D1','D2'],loc='upper right', fontsize=22)
plt.savefig("CPU_cores_used_PDF.pdf", format="pdf", bbox_inches="tight")
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Correlation

# %%
d2.columns
# Out:
# Index(['Time', 'Unnamed: 0', 'Series', 'Time.1', '$\ CPU $', '$\ T_{CPU_1} $',
#        '$\ T_{CPU_2} $', 'Ram', '$\ R_x $', 'CPU_cores', '$\ N_{CPU_x} $',
#        '$\ P_c $', '$\ N_{R_x} $', '$\ N_{T_x} $', '$\ N_{vm} $'],
#       dtype='object')

# %%
d1.rename(columns={'CPU_Load': r"$\ CPU $",'Power':r"$\ P_c $",'Network_RX':r"$\ N_{R_x} $",'Network_TX':r"$\ N_{T_x} $",'CPU1_Temperature':r"$\ T_{CPU_1} $",'CPU2_Temperature':r"$\ T_{CPU_2} $",'Ram_Used':r"$\ R_x $",'CPU_cores_used': r"$\ N_{CPU_x} $",'Fan_speed1':r"$\ f_{s_1} $",'Fan_speed2':r"$\ f_{s_2} $",'Fan_speed3':r"$\ f_{s_3} $",'Fan_speed4':r"$\ f_{s_4} $",'No_Of_Running_vms':r"$\ N_{vm} $",'Inlet_Temperature':r"$\ T_{in} $" }, inplace=True)
d2.rename(columns={'CPU_Load': r"$\ CPU $",'Power':r"$\ P_c $",'Network_RX':r"$\ N_{R_x} $",'Network_TX':r"$\ N_{T_x} $",'CPU1_Temperature':r"$\ T_{CPU_1} $",'CPU2_Temperature':r"$\ T_{CPU_2} $",'Ram_Used':r"$\ R_x $",'CPU_cores_used': r"$\ N_{CPU_x} $",'Fan_speed1':r"$\ f_{s_1} $",'Fan_speed2':r"$\ f_{s_2} $",'Fan_speed3':r"$\ f_{s_3} $",'Fan_speed4':r"$\ f_{s_4} $",'No_Of_Running_vms':r"$\ N_{vm} $",'Inlet_Temperature':r"$\ T_{in} $" }, inplace=True)

# %%
d1_1=d1.drop(['Ram','CPU_cores'], axis=1)
d2_2=d2.drop(['Unnamed: 0','Ram','CPU_cores'], axis=1)

# %%
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(d1.corr(), vmin=-1, vmax=1,  cmap='vlag')
#heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
plt.xticks(rotation=90)
#plt.savefig("d1_Heatmap.pdf", format="pdf", bbox_inches="tight")

# %%
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(d2.corr(), vmin=-1, vmax=1,  cmap='vlag')
#heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
plt.xticks(rotation=90)
#plt.savefig("d2_Heatmap.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# Cumulative Distribution Function (CDF)

# %%
plt.figure(figsize=(8, 6))
x1 = np.sort(d1['CPU_Load'])
y1 = np.arange(1, len(x1)+1) / len(x1)
x2 = np.sort(d2['CPU_Load'])
y2 = np.arange(1, len(x2)+1) / len(x2)

plt.hist(x1, density=True, cumulative=True, label='CDF', histtype='step')
plt.hist(x2, density=True, cumulative=True, label='CDF', histtype='step')
plt.xlabel( r"$\ CPU (\%) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='lower right', fontsize=22)
#plt.savefig("CDF_CPU_Load.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 6))
x1 = np.sort(d1['CPU_cores_used'])
y1 = np.arange(1, len(x1)+1) / len(x1)
x2 = np.sort(d2['CPU_cores_used'])
y2 = np.arange(1, len(x2)+1) / len(x2)

plt.hist(x1, density=True, cumulative=True, label='CDF', histtype='step')
plt.hist(x2, density=True, cumulative=True, label='CDF', histtype='step')
plt.xlabel( r"$\ N_{CPU_x} $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='lower right', fontsize=22)
#plt.savefig("CDF_CPU_cores_used.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 6))
x1 = np.sort(d1['Ram_Used'])
y1 = np.arange(1, len(x1)+1) / len(x1)
x2 = np.sort(d2['Ram_Used'])
y2 = np.arange(1, len(x2)+1) / len(x2)

plt.hist(x1, density=True, cumulative=True, label='CDF', histtype='step')
plt.hist(x2, density=True, cumulative=True, label='CDF', histtype='step')
plt.xlabel( r"$\ R_x(GB) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='lower right', fontsize=22)
#plt.savefig("CDF_Ram_Used.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 6))
x1 = np.sort(d1['CPU1_Temperature'])
y1 = np.arange(1, len(x1)+1) / len(x1)
x2 = np.sort(d2['CPU1_Temperature'])
y2 = np.arange(1, len(x2)+1) / len(x2)

plt.hist(x1, density=True, cumulative=True, label='CDF', histtype='step')
plt.hist(x2, density=True, cumulative=True, label='CDF', histtype='step')
plt.xlabel( r"$\ T_{CPU_1}(°C) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='upper left', fontsize=22)
#plt.savefig("CDF_CPU1_Temperature.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 6))
x1 = np.sort(d1['CPU2_Temperature'])
y1 = np.arange(1, len(x1)+1) / len(x1)
x2 = np.sort(d2['CPU2_Temperature'])
y2 = np.arange(1, len(x2)+1) / len(x2)

plt.hist(x1, density=True, cumulative=True, label='CDF', histtype='step')
plt.hist(x2, density=True, cumulative=True, label='CDF', histtype='step')
plt.xlabel( r"$\ T_{CPU_2}(°C) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='upper left', fontsize=22)
#plt.savefig("CDF_CPU2_Temperature.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 6))
x1 = np.sort(d1['No_Of_Running_vms'])
y1 = np.arange(1, len(x1)+1) / len(x1)
x2 = np.sort(d2['No_Of_Running_vms'])
y2 = np.arange(1, len(x2)+1) / len(x2)

plt.hist(x1, density=True, cumulative=True, label='CDF', histtype='step')
plt.hist(x2, density=True, cumulative=True, label='CDF', histtype='step')
plt.xlabel( r"$\ N_{vm}  $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='lower right', fontsize=22)
#plt.savefig("CDF_No_Of_Running_vms.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 6))
x1 = np.sort(d1['Network_TX'])
y1 = np.arange(1, len(x1)+1) / len(x1)
x2 = np.sort(d2['Network_TX'])
y2 = np.arange(1, len(x2)+1) / len(x2)

plt.hist(x1, density=True, cumulative=True, label='CDF', histtype='step')
plt.hist(x2, density=True, cumulative=True, label='CDF', histtype='step')
plt.xlabel( r"$\ N_{T_x}(Kbps)  $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='lower right', fontsize=22)
#plt.savefig("CDF_Network_TX.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 6))
x1 = np.sort(d1['Network_RX'])
y1 = np.arange(1, len(x1)+1) / len(x1)
x2 = np.sort(d2['Network_RX'])
y2 = np.arange(1, len(x2)+1) / len(x2)

plt.hist(x1, density=True, cumulative=True, label='CDF', histtype='step')
plt.hist(x2, density=True, cumulative=True, label='CDF', histtype='step')
plt.xlabel( r"$\ N_{R_x}(Kbps)  $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='lower right', fontsize=22)
#plt.savefig("CDF_Network_RX.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
from statsmodels.distributions.empirical_distribution import ECDF
from matplotlib import pyplot
plt.figure(figsize=(8, 6))
ecdf1=ECDF(d1['CPU_Load'])
ecdf2=ECDF(d2['CPU_Load'])
pyplot.plot(ecdf1.x, ecdf1.y*100,linewidth=2)
pyplot.plot(ecdf2.x, ecdf2.y*100,linewidth=2)
plt.xlabel( r"$\ CPU (\%) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='lower right', fontsize=22)
#plt.savefig("CDF_CPU_Load.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 6))
x1 = np.sort(d1['CPU_Load'])
y1 = np.arange(1, len(x1)+1) / len(x1)
x2 = np.sort(d2['CPU_Load'])
y2 = np.arange(1, len(x2)+1) / len(x2)

plt.plot(x1,y1)
plt.plot(x2,y2)
plt.xlabel( r"$\ CPU (\%) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.margins(0.02)  # keep data off plot edges
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
plt.legend(labels = ['D1','D2'],loc='lower right', fontsize=22)
#plt.savefig("CDF_CPU_Load.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# Basic Statistics

# %% [markdown]
# RAM

# %%
dfr1 = d1[['Series','Ram_Used']]
dfr2 = d2[['Series','Ram_Used']]

# %%
dfr1_Series = dfr1.groupby('Series')
dfr2_Series = dfr2.groupby('Series')
dfr1_Series.head
dfr2_Series.head
# Out:
# <bound method GroupBy.head of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000026B3AC8EA40>>

# %%
dfr1_Series_stat = dfr1_Series['Ram_Used'].describe()
dfr2_Series_stat = dfr2_Series['Ram_Used'].describe()

# %%
dfr_1=pd.DataFrame(dfr1_Series_stat)
dfr_2=pd.DataFrame(dfr2_Series_stat)

# %%
plt.xlabel( r"$\ R_x(GB) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(dfr_1,x='mean',marker='^')
sns.ecdfplot(dfr_1,x='max',marker='+')
sns.ecdfplot(dfr_1,x='25%',marker='.')
sns.ecdfplot(dfr_1,x='75%',marker='*')
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.legend(labels = ['mean','max','25%','75%'],fontsize=14)
#plt.savefig("D1_Stat_Ram_used .pdf", format="pdf", bbox_inches="tight")

# %%
plt.xlabel( r"$\ R_x(GB) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(dfr_2,x='mean',marker='^')
sns.ecdfplot(dfr_2,x='max',marker='+')
sns.ecdfplot(dfr_2,x='25%',marker='.')
sns.ecdfplot(dfr_2,x='75%',marker='*')
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.legend(labels = ['mean','max','25%','75%'],fontsize=14)
#plt.savefig("D2_Stat_Ram_used .pdf", format="pdf", bbox_inches="tight")

# %%
#Coff. Of variation
CoVr1 = (dfr_1['std']/(dfr_1['mean']))
CoVr2 = (dfr_2['std']/(dfr_2['mean']))

# %%
CoVr1.describe()
# Out:
# count    81.000000
# mean      0.355903
# std       0.190732
# min       0.119247
# 25%       0.225342
# 50%       0.309309
# 75%       0.396938
# max       1.041985
# dtype: float64

# %%
CoVr2.describe()
# Out:
# count    62.000000
# mean      0.568612
# std       0.246030
# min       0.013648
# 25%       0.411883
# 50%       0.495591
# 75%       0.661261
# max       1.757597
# dtype: float64

# %%
CoVr1.median()
# Out:
# 0.309309272077805

# %%
CoVr2.median()
# Out:
# 0.4955914184368517

# %%
plt.xlabel( r"$\ Coefficient\ Of\ Variation $", fontsize=18)
plt.ylabel(r"$\ CDF $", fontsize=18)
box_style=dict(boxstyle='round', facecolor='white', alpha=0.5)
plt.text( 0.75,0.2 , 'mean = 0.36\nmedian = 0.31\nmax = 1.04\nmin = 0.12\nQ1 = 0.23\nQ3 = 0.40',bbox=box_style,fontsize=14)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(CoVr1,linewidth=2.5)
#plt.savefig("D1_CoV_Ram_used .pdf", format="pdf", bbox_inches="tight")

# %%
plt.xlabel( r"$\ Coefficient\ Of\ Variation $", fontsize=18)
plt.ylabel(r"$\ CDF $", fontsize=18)
box_style=dict(boxstyle='round', facecolor='white', alpha=0.5)
plt.text( 1.20,0.2 , 'mean = 0.57\nmedian = 0.50\nmax = 1.76\nmin = 0.01\nQ1 = 0.41\nQ3 = 0.66',bbox=box_style,fontsize=14)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(CoVr2,linewidth=2.5)
#plt.savefig("D2_CoV_Ram_used .pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# CPU Load

# %%
dl1 = d1[['Series','CPU_Load']]
dl2 = d2[['Series','CPU_Load']]

# %%
dl1_Series = dl1.groupby('Series')
dl2_Series = dl2.groupby('Series')
dl1_Series.head
dl2_Series.head
# Out:
# <bound method GroupBy.head of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000026B87F9F190>>

# %%
dl1_Series_stat = dl1_Series['CPU_Load'].describe()
dl2_Series_stat = dl2_Series['CPU_Load'].describe()

# %%
dl_1=pd.DataFrame(dl1_Series_stat)
dl_2=pd.DataFrame(dl2_Series_stat)

# %%
plt.xlabel( r"$\ CPU(\%) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(dl_1,x='mean',marker='^')
sns.ecdfplot(dl_1,x='max',marker='+')
sns.ecdfplot(dl_1,x='25%',marker='.')
sns.ecdfplot(dl_1,x='75%',marker='*')
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.legend(labels = ['mean','max','25%','75%'],fontsize=14)
#plt.savefig("D1_Stat_CPU_Load.pdf", format="pdf", bbox_inches="tight")

# %%
plt.xlabel( r"$\ CPU(\%) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(dl_2,x='mean',marker='^')
sns.ecdfplot(dl_2,x='max',marker='+')
sns.ecdfplot(dl_2,x='25%',marker='.')
sns.ecdfplot(dl_2,x='75%',marker='*')
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.legend(labels = ['mean','max','25%','75%'],fontsize=14)
#plt.savefig("D2_Stat_CPU_Load.pdf", format="pdf", bbox_inches="tight")

# %%
#Coff. Of variation
CoVl1 = (dl_1['std']/(dl_1['mean']))
CoVl2 = (dl_2['std']/(dl_2['mean']))

# %%
CoVl1.describe()
# Out:
# count    81.000000
# mean      1.177665
# std       0.515923
# min       0.441630
# 25%       0.897845
# 50%       1.022275
# 75%       1.264227
# max       3.360049
# dtype: float64

# %%
CoVl2.describe()
# Out:
# count    62.000000
# mean      0.767104
# std       0.437152
# min       0.129526
# 25%       0.525079
# 50%       0.621148
# 75%       0.905004
# max       3.212357
# dtype: float64

# %%
CoVl1.median()
# Out:
# 1.0222748775512687

# %%
CoVl2.median()
# Out:
# 0.6211478679146384

# %%
plt.xlabel( r"$\ Coefficient\ Of\ Variation $", fontsize=18)
plt.ylabel(r"$\ CDF $", fontsize=18)
box_style=dict(boxstyle='round', facecolor='white', alpha=0.5)
plt.text( 2.4,0.2 , 'mean = 1.18\nmedian = 1.02\nmax = 3.36\nmin = 0.44\nQ1 = 0.90\nQ3 = 1.26',bbox=box_style,fontsize=14)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(CoVl1,linewidth=2.5)
#plt.savefig("D1_CoV_CPU_Load.pdf", format="pdf", bbox_inches="tight")

# %%
plt.xlabel( r"$\ Coefficient\ Of\ Variation $", fontsize=18)
plt.ylabel(r"$\ CDF $", fontsize=18)
box_style=dict(boxstyle='round', facecolor='white', alpha=0.5)
plt.text( 2.2,0.2 , 'mean = 0.77\nmedian = 0.62\nmax = 3.21\nmin = 0.13\nQ1 = 0.53\nQ3 = 0.91',bbox=box_style,fontsize=14)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(CoVl2,linewidth=2.5)
#plt.savefig("D2_CoV_CPU_Load.pdf", format="pdf", bbox_inches="tight")

# %%
dp1 = d1[['Series','Power']]
dp2 = d2[['Series','Power']]

# %%
dp1_Series = dp1.groupby('Series')
dp2_Series = dp2.groupby('Series')
dp1_Series.head
dp2_Series.head
# Out:
# <bound method GroupBy.head of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000026B9754A2F0>>

# %%
dp1_Series_stat = dp1_Series['Power'].describe()
dp2_Series_stat = dp2_Series['Power'].describe()

# %%
dp_1=pd.DataFrame(dp1_Series_stat)
dp_2=pd.DataFrame(dp2_Series_stat)

# %%
plt.xlabel( r"$\ P_c(Watt) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(dp_1,x='mean',marker='^')
sns.ecdfplot(dp_1,x='max',marker='+')
sns.ecdfplot(dp_1,x='25%',marker='.')
sns.ecdfplot(dp_1,x='75%',marker='*')
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.legend(labels = ['mean','max','25%','75%'],fontsize=14)
#plt.savefig("D1_Stat_Power.pdf", format="pdf", bbox_inches="tight")

# %%
plt.xlabel( r"$\ P_c(Watt) $", fontsize=24)
plt.ylabel(r"$\ CDF $", fontsize=24)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(dp_2,x='mean',marker='^')
sns.ecdfplot(dp_2,x='max',marker='+')
sns.ecdfplot(dp_2,x='25%',marker='.')
sns.ecdfplot(dp_2,x='75%',marker='*')
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.legend(labels = ['mean','max','25%','75%'],fontsize=14)
#plt.savefig("D2_Stat_Power.pdf", format="pdf", bbox_inches="tight")

# %%
#Coff. Of variation
CoVp1 = (dp_1['std']/(dp_1['mean']))
CoVp2 = (dp_2['std']/(dp_2['mean']))

# %%
CoVp1.describe()
# Out:
# count    81.000000
# mean      0.238540
# std       0.079126
# min       0.002342
# 25%       0.194400
# 50%       0.254658
# 75%       0.291117
# max       0.372711
# dtype: float64

# %%
CoVp2.describe()
# Out:
# count    62.000000
# mean      0.164749
# std       0.054174
# min       0.006930
# 25%       0.141820
# 50%       0.175779
# 75%       0.184969
# max       0.310214
# dtype: float64

# %%
CoVp1.median()
# Out:
# 0.254658425405091

# %%
CoVp2.median()
# Out:
# 0.17577855944225756

# %%
plt.xlabel( r"$\ Coefficient\ Of\ Variation $", fontsize=18)
plt.ylabel(r"$\ CDF $", fontsize=18)
box_style=dict(boxstyle='round', facecolor='white', alpha=0.5)
plt.text( 0.0,0.525 , 'mean = 0.24\nmedian = 0.25\nmax = 0.37\nmin = 0.002\nQ1 = 0.19\nQ3 = 0.29',bbox=box_style,fontsize=14)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(CoVp1,linewidth=2.5)
#plt.savefig("D1_CoV_Power.pdf", format="pdf", bbox_inches="tight")

# %%
plt.xlabel( r"$\ Coefficient\ Of\ Variation $", fontsize=18)
plt.ylabel(r"$\ CDF $", fontsize=18)
box_style=dict(boxstyle='round', facecolor='white', alpha=0.5)
plt.text( 0.21,0.2 , 'mean = 0.16\nmedian = 0.18\nmax = 0.31\nmin = 0.007\nQ1 = 0.14\nQ3 = 0.18',bbox=box_style,fontsize=14)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.grid(color = 'black', linestyle = '--', linewidth = 0.5)
sns.ecdfplot(CoVp2,linewidth=2.5)
#plt.savefig("D2_CoV_Power.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# Usage Over Time

# %%
from matplotlib.dates import DateFormatter
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
import matplotlib.dates as mdates

# %%
d2=d2.drop('Time', inplace=True, axis=1)
# Out:
# C:\Users\mrjmi\AppData\Local\Temp\ipykernel_15072\1569902667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2=d2.drop('Time.1', inplace=True, axis=1)

# %%
d1 = d1[5::6]
d2 = d2[5::6]

# %%
hour1_mean=d1.resample('H').mean()
hour2_mean=d2.resample('H').mean()

# %%
d1_mean=pd.DataFrame(hour1_mean)
d2_mean=pd.DataFrame(hour2_mean)

# %%
hour1_max=d1.resample('H').max()
hour2_max=d2.resample('H').max()
# Out:
# C:\Users\mrjmi\AppData\Local\Temp\ipykernel_15072\3487248280.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   hour1_max=d1.resample('H').max()

# %%
d1_max=pd.DataFrame(hour1_max)
d2_max=pd.DataFrame(hour2_max)

# %% [markdown]
# Power

# %%
plt.figure(figsize=(20, 8))
p_mean = d1_mean['Power']
p_max = d1_max['Power']
p_ratio = d1_max['Power']/d1_mean['Power']
plt.xlabel( r"$\ Time $", fontsize=24)
plt.ylabel(r"$\ P_c $", fontsize=24)
plt.plot(p_mean,label='mean', lw=2)
plt.plot(p_max,label='max', lw=2)
plt.plot(p_ratio,label='ratio, lw=2')
plt.legend(labels = ['mean','max','peak to mean ratio '],fontsize=18)
plt.yscale('log')
#plt.savefig("D1_peak_to_mean_Power(hourly).pdf", format="pdf", bbox_inches="tight")

# %%
plt.figure(figsize=(20, 8))
date_form = DateFormatter("%Y-%m")
plt.gca().xaxis.set_major_formatter(date_form) 

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
p_mean = d2_mean['Power']
p_max = d2_max['Power']
p_ratio = d2_max['Power']/d2_mean['Power']
plt.xlabel( r"$\ Time $", fontsize=24)
plt.ylabel(r"$\ P_c $", fontsize=24)
plt.plot(p_mean,label='mean', lw=2)
plt.plot(p_max,label='max', lw=2)
plt.plot(p_ratio,label='ratio, lw=2')
plt.legend(labels = ['mean','max','peak to mean ratio '],fontsize=18)
plt.yscale('log')
#plt.savefig("D2_peak_to_mean_Power(hourly) .pdf", format="pdf", bbox_inches="tight")

# %%
plt.figure(figsize=(20, 8))
p_mean = d1_mean['CPU_Load']
p_max = d1_max['CPU_Load']
p_ratio = d1_max['CPU_Load']/d1_mean['CPU_Load']
plt.xlabel( r"$\ Time $", fontsize=24)
plt.ylabel(r"$\ CPU $", fontsize=24)
plt.plot(p_mean,label='mean', lw=2)
plt.plot(p_max,label='max', lw=2)
plt.plot(p_ratio,label='ratio, lw=2')
plt.legend(labels = ['mean','max','peak to mean ratio '],fontsize=18,loc='lower right')
plt.yscale('log')
#plt.savefig("D1_peak_to_mean_CPU_Load(hourly).pdf", format="pdf", bbox_inches="tight")

# %%
plt.figure(figsize=(20, 8))
date_form = DateFormatter("%Y-%m")
plt.gca().xaxis.set_major_formatter(date_form) 

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
p_mean = d2_mean['CPU_Load']
p_max = d2_max['CPU_Load']
p_ratio = d2_max['CPU_Load']/d2_mean['CPU_Load']
plt.xlabel( r"$\ Time $", fontsize=24)
plt.ylabel(r"$\ CPU $", fontsize=24)
plt.plot(p_mean,label='mean', lw=2)
plt.plot(p_max,label='max', lw=2)
plt.plot(p_ratio,label='ratio, lw=2')
plt.legend(labels = ['mean','max','peak to mean ratio '],fontsize=18)
plt.yscale('log')
#plt.savefig("D2_peak_to_mean_CPU_Load(hourly) .pdf", format="pdf", bbox_inches="tight")

# %%
plt.figure(figsize=(20, 8))
p_mean = d1_mean['Ram_Used']
p_max = d1_max['Ram_Used']
p_ratio = d1_max['Ram_Used']/d1_mean['Ram_Used']
plt.xlabel( r"$\ Time $", fontsize=24)
plt.ylabel(r"$\  R_x $", fontsize=24)
plt.plot(p_mean,label='mean', lw=2)
plt.plot(p_max,label='max', lw=2)
plt.plot(p_ratio,label='ratio, lw=2')
plt.legend(labels = ['mean','max','peak to mean ratio '],fontsize=18)
plt.yscale('log')
#plt.savefig("D1_peak_to_mean_RAM(hourly).pdf", format="pdf", bbox_inches="tight")

# %%
plt.figure(figsize=(20, 8))
date_form = DateFormatter("%Y-%m")
plt.gca().xaxis.set_major_formatter(date_form) 
# show every 12th tick on x axes
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
p_mean = d2_mean['Ram_Used']
p_max = d2_max['Ram_Used']
p_ratio = d2_max['Ram_Used']/d2_mean['Ram_Used']
plt.xlabel( r"$\ Time $", fontsize=24)
plt.ylabel(r"$\ R_x $", fontsize=24)
plt.plot(p_mean,label='mean', lw=2)
plt.plot(p_max,label='max', lw=2)
plt.plot(p_ratio,label='ratio, lw=2')
plt.legend(labels = ['mean','max','peak to mean ratio '],fontsize=18,loc='center right')
plt.yscale('log')
#plt.savefig("D2_peak_to_mean_RAM(hourly) .pdf", format="pdf", bbox_inches="tight")

# %%
d1.columns
# Out:
# Index(['Unnamed: 0', 'Series', 'Time', 'CPU_Load', 'Power', 'Network_RX',
#        'Network_TX', 'Inlet_Temperature', 'CPU1_Temperature',
#        'CPU2_Temperature', 'Fan_speed1', 'Fan_speed2', 'Fan_speed3',
#        'Fan_speed4', 'Ram', 'Ram_Used', 'No_Of_Running_vms', 'CPU_cores',
#        'CPU_cores_used'],
#       dtype='object')

# %% [markdown]
# Prediction

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.svm import LinearSVC, SVC
import seaborn as sns
from sklearn.linear_model import Lasso, ElasticNet, Ridge, SGDRegressor
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import os # accessing directory structure
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
## max and min value to calculate NRMSE
maxd2=pd.DataFrame(d2.max()).T    ##.T to transpose dataframe to take assigned value from respected column rather than one column and many rows, it has now one row many column
mind2=pd.DataFrame(d2.min()).T

# %%
d2.columns
# Out:
# Index(['Time', 'Unnamed: 0', 'Series', 'Time.1', 'CPU_Load',
#        'CPU1_Temperature', 'CPU2_Temperature', 'Ram', 'Ram_Used', 'CPU_cores',
#        'CPU_cores_used', 'Power', 'Network_RX', 'Network_TX',
#        'No_Of_Running_vms'],
#       dtype='object')

# %% [markdown]
# Load Prediction

# %%
xc2=d2[['CPU1_Temperature', 'CPU2_Temperature', 'Ram', 'Ram_Used', 'CPU_cores',
       'CPU_cores_used', 'Power', 'Network_RX', 'Network_TX','No_Of_Running_vms']]
yc2 = d2[['CPU_Load']]
xc2_train,xc2_test,yc2_train,yc2_test = train_test_split(xc2,yc2,test_size=0.3,random_state=2)

# %%
linearRegressor = LinearRegression()
linearRegressor.fit(xc2_train, yc2_train)
yc2_predicted = linearRegressor.predict(xc2_test)
mse = mean_squared_error(yc2_test, yc2_predicted)
rc2 = r2_score(yc2_test, yc2_predicted)
mae = mean_absolute_error(yc2_test,yc2_predicted)
rmse=np.sqrt(mean_squared_error(yc2_test,yc2_predicted))
nrmse= rmse/(maxd2['CPU_Load']-mind2['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 41.97361601557227
# R score: 0.8772182547757471
# Mean Absolute Error: 4.3697537019630825
# Root Mean Absolute Error: 6.478704810035126
# Normalised Root Mean Absolute Error: 0    0.075062
# Name: CPU_Load, dtype: object

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)
xc2_poly = polynomial_features.fit_transform(xc2_train)
xc2_poly_test = polynomial_features.fit_transform(xc2_test)
model = LinearRegression()
model.fit(xc2_poly, yc2_train)
yc2_predicted_p = model.predict(xc2_poly_test)
mse = mean_squared_error(yc2_test, yc2_predicted_p)
rc2 = r2_score(yc2_test, yc2_predicted_p)
mae = mean_absolute_error(yc2_test,yc2_predicted_p)
rmse=np.sqrt(mean_squared_error(yc2_test,yc2_predicted_p))
nrmse= rmse/(maxd2['CPU_Load']-mind2['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 39.59135792156091
# R score: 0.8841868658729849
# Mean Absolute Error: 4.616306171380924
# Root Mean Absolute Error: 6.292166393346644
# Normalised Root Mean Absolute Error: 0    0.072901
# Name: CPU_Load, dtype: object

# %%
l=Lasso(alpha=0.1)
l.fit(xc2_train, yc2_train)
yc2_res = l.predict(xc2_test)
mse = mean_squared_error(yc2_test, yc2_res)
rc2 = r2_score(yc2_test, yc2_res)
mae = mean_absolute_error(yc2_test,yc2_res)
rmse=np.sqrt(mean_squared_error(yc2_test,yc2_res))
nrmse= rmse/(maxd2['CPU_Load']-mind2['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 41.97303309597148
# R score: 0.8772199599394357
# Mean Absolute Error: 4.365043442301371
# Root Mean Absolute Error: 6.4786598225228245
# Normalised Root Mean Absolute Error: 0    0.075061
# Name: CPU_Load, dtype: object

# %%
ridge=Ridge(alpha=0.1)
ridge.fit(xc2_train, yc2_train)
yc2_res = ridge.predict(xc2_test)
mse = mean_squared_error(yc2_test, yc2_res)
rc2 = r2_score(yc2_test, yc2_res)
mae = mean_absolute_error(yc2_test,yc2_res)
rmse=np.sqrt(mean_squared_error(yc2_test,yc2_res))
nrmse= rmse/(maxd2['CPU_Load']-mind2['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 41.97362481543094
# R score: 0.8772182290342907
# Mean Absolute Error: 4.369754438683854
# Root Mean Absolute Error: 6.478705489172273
# Normalised Root Mean Absolute Error: 0    0.075062
# Name: CPU_Load, dtype: object
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=2.75732e-24): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
SGD=SGDRegressor(max_iter=1000, tol=1e-3)
SGD.fit(xc2_train, yc2_train)
yc2_res = SGD.predict(xc2_test)
mse = mean_squared_error(yc2_test, yc2_res)
rc2 = r2_score(yc2_test, yc2_res)
mae = mean_absolute_error(yc2_test,yc2_res)
rmse=np.sqrt(mean_squared_error(yc2_test,yc2_res))
nrmse= rmse/(maxd2['CPU_Load']-mind2['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Squared Error: 5.988882023591619e+49
# R score: -1.7518752411656112e+47
# Mean Absolute Error: 1.017322936381233e+24
# Root Mean Absolute Error: 7.738786741855353e+24
# Normalised Root Mean Absolute Error: 0    89660958254257093476352.0
# Name: CPU_Load, dtype: object

# %%
# Decision Tree
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(xc2_train, yc2_train)
yc2_predicted_d = regressor.predict(xc2_test)
mse = mean_squared_error(yc2_test, yc2_predicted_d)
rc2 = r2_score(yc2_test, yc2_predicted_d)
mae = mean_absolute_error(yc2_test,yc2_predicted_d)
rmse=np.sqrt(mean_squared_error(yc2_test,yc2_predicted_d))
nrmse= rmse/(maxd2['CPU_Load']-mind2['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 9.993531886701078
# R score: 0.970766795847464
# Mean Absolute Error: 1.5364436720994532
# Root Mean Absolute Error: 3.1612547962321984
# Normalised Root Mean Absolute Error: 0    0.036626
# Name: CPU_Load, dtype: object

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=0, n_estimators=300)
rf.fit(xc2_train,yc2_train)
yc2_predicted_r = rf.predict(xc2_test)

mse = mean_squared_error(yc2_test, yc2_predicted_r)
rc2 = r2_score(yc2_test, yc2_predicted_r)
mae = mean_absolute_error(yc2_test,yc2_predicted_r)
rmse=np.sqrt(mean_squared_error(yc2_test,yc2_predicted_r))
nrmse= rmse/(maxd2['CPU_Load']-mind2['CPU_Load'])

print("Mean Squared Error:",mse)
print("R score:",rc2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# C:\Users\mrjmi\AppData\Local\Temp\ipykernel_27512\394551629.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(xc2_train,yc2_train)
# Mean Squared Error: 4.815003159417134
# R score: 0.9859150926869348
# Mean Absolute Error: 1.1783971247111724
# Root Mean Absolute Error: 2.194311545660081
# Normalised Root Mean Absolute Error: 0    0.025423
# Name: CPU_Load, dtype: object

# %%
#XGBoost
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score
# fit model no training data
model = XGBRegressor()
model.fit(xc2_train, yc2_train)
# make predictions for test data
yc2_pred = model.predict(xc2_test)
predictions = [round(value) for value in yc2_pred]
rmse = np.sqrt(mean_squared_error(yc2_test, predictions))
nrmse= rmse/(maxd2['CPU_Load']-mind2['CPU_Load'])
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Root Mean Absolute Error: 2.806455977201178
# Normalised Root Mean Absolute Error: 0    0.032515
# Name: CPU_Load, dtype: object

# %%
#lgbm model   
import lightgbm as lgb
model = lgb.LGBMRegressor(learning_rate=0.01,max_depth=20,random_state=42)
model.fit(xc2_train,yc2_train,eval_set=[(xc2_test,yc2_test),(xc2_train,yc2_train)],
          verbose=20,eval_metric='logloss')
print('Training accuracy {:.4f} '.format(model.score(xc2_train,yc2_train)))
print('Testing accuracy {:.4f}'.format(model.score(xc2_test,yc2_test)))
yc2_pred = model.predict(xc2_test)
rmse = np.sqrt(mean_squared_error(yc2_test, yc2_pred))
nrmse= rmse/(maxd2['CPU_Load']-mind2['CPU_Load'])
print("MSE",mean_squared_error(yc2_test,yc2_pred))
print("RMSE",np.sqrt(mean_squared_error(yc2_test,yc2_pred)))
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [20]	training's l2: 233.832	valid_0's l2: 233.584
# [40]	training's l2: 161.152	valid_0's l2: 160.993
# [60]	training's l2: 112.36	valid_0's l2: 112.259
# [80]	training's l2: 79.5602	valid_0's l2: 79.4975
# [100]	training's l2: 57.4522	valid_0's l2: 57.4159
# Training accuracy 0.8321
# Testing accuracy 0.8320
# MSE 57.415870033046374
# RMSE 7.577326047692971
# Normalised Root Mean Absolute Error: 0    0.08779
# Name: CPU_Load, dtype: object

# %%
# Neural Networks
import warnings
warnings.filterwarnings('ignore')
from keras.models import Sequential,model_from_json
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(10,)))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='relu'))
model.summary()
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model.fit(xc2_train,yc2_train,batch_size=100,epochs=10,verbose=1)
test=model.evaluate(xc2_test, yc2_test, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 256)               2816
#
#  dense_6 (Dense)             (None, 256)               65792
#
#  dense_7 (Dense)             (None, 256)               65792
#
#  dense_8 (Dense)             (None, 256)               65792
#
#  dense_9 (Dense)             (None, 1)                 257
#
# ...
# Total params: 200,449
# Trainable params: 200,449
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 6729/6729 [==============================] - 17s 2ms/step - loss: 844.9039 - root_mean_squared_error: 29.0672
# Epoch 2/20
# 6729/6729 [==============================] - 16s 2ms/step - loss: 844.9029 - root_mean_squared_error: 29.0672
# Epoch 3/20
# 6729/6729 [==============================] - 17s 3ms/step - loss: 844.9052 - root_mean_squared_error: 29.0673
# ...

# %%
nrmse= 29.0316/(maxd2['CPU_Load']-mind2['CPU_Load'])
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Normalised Root Mean Absolute Error: 0    0.336358
# Name: CPU_Load, dtype: object

# %% [markdown]
# Removing 196-200 in D1

# %%
d11 = d1.dropna()
d11
# Out:
#                               Unnamed: 0       Series                 Time  \
# Time
# 2018-10-09 11:20:00  2018-10-09 11:20:00  qh2-rcc120   2018-10-09 11:20:00
# 2018-10-09 11:30:00  2018-10-09 11:30:00  qh2-rcc120   2018-10-09 11:30:00
# 2018-10-09 11:40:00  2018-10-09 11:40:00  qh2-rcc120   2018-10-09 11:40:00
# 2018-10-09 11:50:00  2018-10-09 11:50:00  qh2-rcc120   2018-10-09 11:50:00
# 2018-10-09 12:00:00  2018-10-09 12:00:00  qh2-rcc120   2018-10-09 12:00:00
# ...                                  ...          ...                  ...
# 2019-06-20 09:20:00  2019-06-20 09:20:00  qh2-rcc195   2019-06-20 09:20:00
# 2019-06-20 09:30:00  2019-06-20 09:30:00  qh2-rcc195   2019-06-20 09:30:00
# 2019-06-20 09:40:00  2019-06-20 09:40:00  qh2-rcc195   2019-06-20 09:40:00
# 2019-06-20 09:50:00  2019-06-20 09:50:00  qh2-rcc195   2019-06-20 09:50:00
# 2019-06-20 10:00:00  2019-06-20 10:00:00  qh2-rcc195   2019-06-20 10:00:00
#
# ...

# %%
d11.isnull().sum()
# Out:
# Unnamed: 0           0
# Series               0
# Time                 0
# CPU_Load             0
# Power                0
# Network_RX           0
# Network_TX           0
# Inlet_Temperature    0
# CPU1_Temperature     0
# CPU2_Temperature     0
# Fan_speed1           0
# Fan_speed2           0
# Fan_speed3           0
# Fan_speed4           0
# Ram                  0
# Ram_Used             0
# No_Of_Running_vms    0
# CPU_cores            0
# CPU_cores_used       0
# dtype: int64

# %%
## max and min value to calculate NRMSE
maxd1=pd.DataFrame(d11.max()).T    ##.T to transpose dataframe to take assigned value from respected column rather than one column and many rows, it has now one row many column
mind1=pd.DataFrame(d11.min()).T

# %%
d11.columns
# Out:
# Index(['Unnamed: 0', 'Series', 'Time', 'CPU_Load', 'Power', 'Network_RX',
#        'Network_TX', 'Inlet_Temperature', 'CPU1_Temperature',
#        'CPU2_Temperature', 'Fan_speed1', 'Fan_speed2', 'Fan_speed3',
#        'Fan_speed4', 'Ram', 'Ram_Used', 'No_Of_Running_vms', 'CPU_cores',
#        'CPU_cores_used'],
#       dtype='object')

# %%
xc1=d11[['Power', 'Network_RX','Network_TX', 'Inlet_Temperature', 'CPU1_Temperature',
       'CPU2_Temperature', 'Fan_speed1', 'Fan_speed2', 'Fan_speed3',
       'Fan_speed4', 'Ram', 'Ram_Used', 'No_Of_Running_vms', 'CPU_cores','CPU_cores_used']]
yc1 = d11[['CPU_Load']]
xc1_train,xc1_test,yc1_train,yc1_test = train_test_split(xc1,yc1,test_size=0.3,random_state=2)

# %%
linearRegressor = LinearRegression()
linearRegressor.fit(xc1_train, yc1_train)
yc1_predicted = linearRegressor.predict(xc1_test)
mse = mean_squared_error(yc1_test, yc1_predicted)
rc1 = r2_score(yc1_test, yc1_predicted)
mae = mean_absolute_error(yc1_test,yc1_predicted)
rmse=np.sqrt(mean_squared_error(yc1_test,yc1_predicted))
nrmse= rmse/(maxd1['CPU_Load']-mind1['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 16.985092215014664
# R score: 0.9171301162457908
# Mean Absolute Error: 2.726604054900933
# Root Mean Absolute Error: 4.121297394633717
# Normalised Root Mean Absolute Error: 0    0.060286
# Name: CPU_Load, dtype: object

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)
xc1_poly = polynomial_features.fit_transform(xc1_train)
xc1_poly_test = polynomial_features.fit_transform(xc1_test)
model = LinearRegression()
model.fit(xc1_poly, yc1_train)
yc1_predicted_p = model.predict(xc1_poly_test)
mse = mean_squared_error(yc1_test, yc1_predicted_p)
rc1 = r2_score(yc1_test, yc1_predicted_p)
mae = mean_absolute_error(yc1_test,yc1_predicted_p)
rmse=np.sqrt(mean_squared_error(yc1_test,yc1_predicted_p))
nrmse= rmse/(maxd1['CPU_Load']-mind1['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 17.785730528211165
# R score: 0.913223819882848
# Mean Absolute Error: 2.9285874562735263
# Root Mean Absolute Error: 4.217313188300244
# Normalised Root Mean Absolute Error: 0    0.06169
# Name: CPU_Load, dtype: object

# %%
ridge=Ridge(alpha=0.1)
ridge.fit(xc1_train, yc1_train)
yc1_res = ridge.predict(xc1_test)
mse = mean_squared_error(yc1_test, yc1_res)
rc1 = r2_score(yc1_test, yc1_res)
mae = mean_absolute_error(yc1_test,yc1_res)
rmse=np.sqrt(mean_squared_error(yc1_test,yc1_res))
nrmse= rmse/(maxd1['CPU_Load']-mind1['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 16.985133647142984
# R score: 0.9171299140993664
# Mean Absolute Error: 2.7267325822068575
# Root Mean Absolute Error: 4.121302421218684
# Normalised Root Mean Absolute Error: 0    0.060286
# Name: CPU_Load, dtype: object
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=2.44055e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
l=Lasso(alpha=0.1)
l.fit(xc1_train, yc1_train)
yc1_res = l.predict(xc1_test)
mse = mean_squared_error(yc1_test, yc1_res)
rc1 = r2_score(yc1_test, yc1_res)
mae = mean_absolute_error(yc1_test,yc1_res)
rmse=np.sqrt(mean_squared_error(yc1_test,yc1_res))
nrmse= rmse/(maxd1['CPU_Load']-mind1['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 24.387464778714918
# R score: 0.8810141066243111
# Mean Absolute Error: 3.506139379569798
# Root Mean Absolute Error: 4.938366610400135
# Normalised Root Mean Absolute Error: 0    0.072238
# Name: CPU_Load, dtype: object
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.269e+07, tolerance: 3.817e+04
#   model = cd_fast.enet_coordinate_descent(

# %%
SGD=SGDRegressor(max_iter=1000, tol=1e-3)
SGD.fit(xc1_train, yc1_train)
yc1_res = SGD.predict(xc1_test)
mse = mean_squared_error(yc1_test, yc1_res)
rc1 = r2_score(yc1_test, yc1_res)
mae = mean_absolute_error(yc1_test,yc1_res)
rmse=np.sqrt(mean_squared_error(yc1_test,yc1_res))
nrmse= rmse/(maxd1['CPU_Load']-mind1['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Squared Error: 1.2125731534085105e+46
# R score: -5.916117204097939e+43
# Mean Absolute Error: 1.8085332332786208e+22
# Root Mean Absolute Error: 1.1011689940279423e+23
# Normalised Root Mean Absolute Error: 0    1610775365737550184448.0
# Name: CPU_Load, dtype: object

# %%
# Decision Tree
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(xc1_train, yc1_train)
yc1_predicted_d = regressor.predict(xc1_test)
mse = mean_squared_error(yc1_test, yc1_predicted_d)
rc1 = r2_score(yc1_test, yc1_predicted_d)
mae = mean_absolute_error(yc1_test,yc1_predicted_d)
rmse=np.sqrt(mean_squared_error(yc1_test,yc1_predicted_d))
nrmse= rmse/(maxd1['CPU_Load']-mind1['CPU_Load'])
print("Mean Squared Error:",mse)
print("R score:",rc1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 2.1605129359813287
# R score: 0.9894589058694678
# Mean Absolute Error: 0.517883463842634
# Root Mean Absolute Error: 1.469868339675812
# Normalised Root Mean Absolute Error: 0    0.021501
# Name: CPU_Load, dtype: object

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=0, n_estimators=300)
rf.fit(xc1_train,yc1_train)
yc1_predicted_r = rf.predict(xc1_test)

mse = mean_squared_error(yc1_test, yc1_predicted_r)
rc1 = r2_score(yc1_test, yc1_predicted_r)
mae = mean_absolute_error(yc1_test,yc1_predicted_r)
rmse=np.sqrt(mean_squared_error(yc1_test,yc1_predicted_r))
nrmse= rmse/(maxd1['CPU_Load']-mind1['CPU_Load'])

print("Mean Squared Error:",mse)
print("R score:",rc1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# C:\Users\mrjmi\AppData\Local\Temp\ipykernel_5872\2785484034.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(xc1_train,yc1_train)
# Mean Squared Error: 0.9904704871317677
# R score: 0.9951675167204552
# Mean Absolute Error: 0.4003148139217575
# Root Mean Absolute Error: 0.9952238377027389
# Normalised Root Mean Absolute Error: 0    0.014558
# Name: CPU_Load, dtype: object

# %%
#XGBoost
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score
# fit model no training data
model = XGBRegressor()
model.fit(xc1_train, yc1_train)
# make predictions for test data
yc1_pred = model.predict(xc1_test)
predictions = [round(value) for value in yc1_pred]
rmse = np.sqrt(mean_squared_error(yc1_test, predictions))
nrmse= rmse/(maxd1['CPU_Load']-mind1['CPU_Load'])
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Root Mean Absolute Error: 1.7885535470550447
# Normalised Root Mean Absolute Error: 0    0.026163
# Name: CPU_Load, dtype: object

# %%
#lgbm model   
import lightgbm as lgb
model = lgb.LGBMRegressor(learning_rate=0.01,max_depth=20,random_state=42)
model.fit(xc1_train,yc1_train,eval_set=[(xc1_test,yc1_test),(xc1_train,yc1_train)],
          verbose=20,eval_metric='logloss')
print('Training accuracy {:.4f} '.format(model.score(xc1_train,yc1_train)))
print('Testing accuracy {:.4f}'.format(model.score(xc1_test,yc1_test)))
yc1_pred = model.predict(xc1_test)
rmse = np.sqrt(mean_squared_error(yc1_test, yc1_pred))
nrmse= rmse/(maxd1['CPU_Load']-mind1['CPU_Load'])
print("MSE",mean_squared_error(yc1_test,yc1_pred))
print("RMSE",np.sqrt(mean_squared_error(yc1_test,yc1_pred)))
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# c:\Users\mrjmi\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [20]	training's l2: 140.378	valid_0's l2: 140.061
# [40]	training's l2: 96.6644	valid_0's l2: 96.4615
# [60]	training's l2: 67.2587	valid_0's l2: 67.1333
# [80]	training's l2: 47.4602	valid_0's l2: 47.3863
# [100]	training's l2: 34.1096	valid_0's l2: 34.0691
# Training accuracy 0.8340
# Testing accuracy 0.8338
# MSE 34.06906977256174
# RMSE 5.836871574102153
# Normalised Root Mean Absolute Error: 0    0.085381
# Name: CPU_Load, dtype: object

# %%
# Neural Networks
import warnings
warnings.filterwarnings('ignore')
from keras.models import Sequential,model_from_json
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(15,)))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='relu'))
model.summary()
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model.fit(xc1_train,yc1_train,batch_size=100,epochs=10,verbose=1)
test=model.evaluate(xc1_test, yc1_test, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 256)               4096
#
#  dense_6 (Dense)             (None, 256)               65792
#
#  dense_7 (Dense)             (None, 256)               65792
#
#  dense_8 (Dense)             (None, 256)               65792
#
#  dense_9 (Dense)             (None, 1)                 257
#
# ...
# Total params: 201,729
# Trainable params: 201,729
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 18578/18578 [==============================] - 48s 3ms/step - loss: 19476248.0000 - root_mean_squared_error: 4413.1904
# Epoch 2/10
# 18578/18578 [==============================] - 47s 3ms/step - loss: 318.4367 - root_mean_squared_error: 17.8448
# Epoch 3/10
# ...

# %%
nrmse= 17.8078/(maxd1['CPU_Load']-mind1['CPU_Load'])
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Normalised Root Mean Absolute Error: 0    0.26049
# Name: CPU_Load, dtype: object

# %% [markdown]
# Power Prediction

# %%
xp1=d11[['CPU_Load', 'Network_RX','Network_TX', 'Inlet_Temperature', 'CPU1_Temperature',
       'CPU2_Temperature', 'Fan_speed1', 'Fan_speed2', 'Fan_speed3',
       'Fan_speed4', 'Ram', 'Ram_Used', 'No_Of_Running_vms', 'CPU_cores','CPU_cores_used']]
yp1 = d11[['Power']]
xp1_train,xp1_test,yp1_train,yp1_test = train_test_split(xp1,yp1,test_size=0.3,random_state=2)

# %%
linearRegressor = LinearRegression()
linearRegressor.fit(xp1_train, yp1_train)
yp1_predicted = linearRegressor.predict(xp1_test)
mse = mean_squared_error(yp1_test, yp1_predicted)
rp1 = r2_score(yp1_test, yp1_predicted)
mae = mean_absolute_error(yp1_test,yp1_predicted)
rmse=np.sqrt(mean_squared_error(yp1_test,yp1_predicted))
nrmse= rmse/(maxd1['Power']-mind1['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 184.753354299067
# R score: 0.9575469524705427
# Mean Absolute Error: 10.40569348143627
# Root Mean Absolute Error: 13.592400608393906
# Normalised Root Mean Absolute Error: 0    0.040294
# Name: Power, dtype: object

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)
xp1_poly = polynomial_features.fit_transform(xp1_train)
xp1_poly_test = polynomial_features.fit_transform(xp1_test)
model = LinearRegression()
model.fit(xp1_poly, yp1_train)
yp1_predicted_p = model.predict(xp1_poly_test)
mse = mean_squared_error(yp1_test, yp1_predicted_p)
rp1 = r2_score(yp1_test, yp1_predicted_p)
mae = mean_absolute_error(yp1_test,yp1_predicted_p)
rmse=np.sqrt(mean_squared_error(yp1_test,yp1_predicted_p))
nrmse= rmse/(maxd1['Power']-mind1['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 108.61841730633155
# R score: 0.9750414121033179
# Mean Absolute Error: 7.72499238624467
# Root Mean Absolute Error: 10.422015990504503
# Normalised Root Mean Absolute Error: 0    0.030895
# Name: Power, dtype: object

# %%
ridge=Ridge(alpha=0.1)
ridge.fit(xp1_train, yp1_train)
yp1_res = ridge.predict(xp1_test)
mse = mean_squared_error(yp1_test, yp1_res)
rp1 = r2_score(yp1_test, yp1_res)
mae = mean_absolute_error(yp1_test,yp1_res)
rmse=np.sqrt(mean_squared_error(yp1_test,yp1_res))
nrmse= rmse/(maxd1['Power']-mind1['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 184.75351098281848
# R score: 0.9575469164673925
# Mean Absolute Error: 10.405911007375403
# Root Mean Absolute Error: 13.59240637204533
# Normalised Root Mean Absolute Error: 0    0.040294
# Name: Power, dtype: object

# %%
l=Lasso(alpha=0.1)
l.fit(xp1_train, yp1_train)
yp1_res = l.predict(xp1_test)
mse = mean_squared_error(yp1_test, yp1_res)
rp1 = r2_score(yp1_test, yp1_res)
mae = mean_absolute_error(yp1_test,yp1_res)
rmse=np.sqrt(mean_squared_error(yp1_test,yp1_res))
nrmse= rmse/(maxd1['Power']-mind1['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 260.09342908786107
# R score: 0.9402351380896024
# Mean Absolute Error: 12.487069162813093
# Root Mean Absolute Error: 16.127412349408726
# Normalised Root Mean Absolute Error: 0    0.047809
# Name: Power, dtype: object

# %%
# Decision Tree
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(xp1_train, yp1_train)
yp1_predicted_d = regressor.predict(xp1_test)
mse = mean_squared_error(yp1_test, yp1_predicted_d)
rp1 = r2_score(yp1_test, yp1_predicted_d)
mae = mean_absolute_error(yp1_test,yp1_predicted_d)
rmse=np.sqrt(mean_squared_error(yp1_test,yp1_predicted_d))
nrmse= rmse/(maxd1['Power']-mind1['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 12.04366054631867
# R score: 0.9972325801848563
# Mean Absolute Error: 1.5016411278756205
# Root Mean Absolute Error: 3.470397750448595
# Normalised Root Mean Absolute Error: 0    0.010288
# Name: Power, dtype: object

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=0, n_estimators=300)
rf.fit(xp1_train,yp1_train)
yp1_predicted_r = rf.predict(xp1_test)

mse = mean_squared_error(yp1_test, yp1_predicted_r)
rp1 = r2_score(yp1_test, yp1_predicted_r)
mae = mean_absolute_error(yp1_test,yp1_predicted_r)
rmse=np.sqrt(mean_squared_error(yp1_test,yp1_predicted_r))
nrmse= rmse/(maxd1['Power']-mind1['Power'])

print("Mean Squared Error:",mse)
print("R score:",rp1)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 5.072764546770876
# R score: 0.9988343685816864
# Mean Absolute Error: 1.1208671188125998
# Root Mean Absolute Error: 2.252279855340112
# Normalised Root Mean Absolute Error: 0    0.006677
# Name: Power, dtype: object

# %%
#XGBoost
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score
# fit model no training data
model = XGBRegressor()
model.fit(xp1_train, yp1_train)
# make predictions for test data
yp1_pred = model.predict(xp1_test)
predictions = [round(value) for value in yp1_pred]
rmse = np.sqrt(mean_squared_error(yp1_test, predictions))
nrmse= rmse/(maxd1['Power']-mind1['Power'])
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Root Mean Absolute Error: 4.665276735738713
# Normalised Root Mean Absolute Error: 0    0.01383
# Name: Power, dtype: object

# %%
#lgbm model   
import lightgbm as lgb
model = lgb.LGBMRegressor(learning_rate=0.01,max_depth=20,random_state=42)
model.fit(xp1_train,yp1_train,eval_set=[(xp1_test,yp1_test),(xp1_train,yp1_train)],
          verbose=20,eval_metric='logloss')
print('Training accuracy {:.4f} '.format(model.score(xp1_train,yp1_train)))
print('Testing accuracy {:.4f}'.format(model.score(xp1_test,yp1_test)))
yp1_pred = model.predict(xp1_test)
rmse = np.sqrt(mean_squared_error(yp1_test, yp1_pred))
nrmse= rmse/(maxd1['Power']-mind1['Power'])
print("MSE",mean_squared_error(yp1_test,yp1_pred))
print("RMSE",np.sqrt(mean_squared_error(yp1_test,yp1_pred)))
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# [20]	training's l2: 2961.55	valid_0's l2: 2955.45
# [40]	training's l2: 2022.36	valid_0's l2: 2018.25
# [60]	training's l2: 1390.3	valid_0's l2: 1387.59
# [80]	training's l2: 963.877	valid_0's l2: 962.053
# [100]	training's l2: 675.595	valid_0's l2: 674.387
# Training accuracy 0.8451
# Testing accuracy 0.8450
# MSE 674.3870380787199
# RMSE 25.96896297657494
# Normalised Root Mean Absolute Error: 0    0.076983
# Name: Power, dtype: object

# %%
# Neural Networks
import warnings
warnings.filterwarnings('ignore')
from keras.models import Sequential,model_from_json
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(15,)))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='relu'))
model.summary()
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model.fit(xp1_train,yp1_train,batch_size=100,epochs=10,verbose=1)
test=model.evaluate(xp1_test, yp1_test, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 256)               4096
#
#  dense_6 (Dense)             (None, 256)               65792
#
#  dense_7 (Dense)             (None, 256)               65792
#
#  dense_8 (Dense)             (None, 256)               65792
#
#  dense_9 (Dense)             (None, 1)                 257
#
# ...
# Total params: 201,729
# Trainable params: 201,729
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 18578/18578 [==============================] - 44s 2ms/step - loss: 135145808.0000 - root_mean_squared_error: 11625.2227
# Epoch 2/10
# 18578/18578 [==============================] - 41s 2ms/step - loss: 46396.3203 - root_mean_squared_error: 215.3981
# Epoch 3/10
# ...

# %%
nrmse= 215.1793/(maxd1['Power']-mind1['Power'])
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Normalised Root Mean Absolute Error: 0    0.637883
# Name: Power, dtype: object

# %% [markdown]
# D2 power

# %%
xp2=d2[['CPU1_Temperature', 'CPU2_Temperature', 'Ram', 'Ram_Used', 'CPU_cores',
       'CPU_cores_used', 'CPU_Load', 'Network_RX', 'Network_TX','No_Of_Running_vms']]
yp2 = d2[['Power']]
xp2_train,xp2_test,yp2_train,yp2_test = train_test_split(xp2,yp2,test_size=0.3,random_state=2)

# %%
linearRegressor = LinearRegression()
linearRegressor.fit(xp2_train, yp2_train)
yp2_predicted = linearRegressor.predict(xp2_test)
mse = mean_squared_error(yp2_test, yp2_predicted)
rp2 = r2_score(yp2_test, yp2_predicted)
mae = mean_absolute_error(yp2_test,yp2_predicted)
rmse=np.sqrt(mean_squared_error(yp2_test,yp2_predicted))
nrmse= rmse/(maxd2['Power']-mind2['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 600.1275818637985
# R score: 0.9614029623327318
# Mean Absolute Error: 18.59994543889737
# Root Mean Absolute Error: 24.497501543296174
# Normalised Root Mean Absolute Error: 0    0.044867
# Name: Power, dtype: object

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)
xp2_poly = polynomial_features.fit_transform(xp2_train)
xp2_poly_test = polynomial_features.fit_transform(xp2_test)
model = LinearRegression()
model.fit(xp2_poly, yp2_train)
yp2_predicted_p = model.predict(xp2_poly_test)
mse = mean_squared_error(yp2_test, yp2_predicted_p)
rp2 = r2_score(yp2_test, yp2_predicted_p)
mae = mean_absolute_error(yp2_test,yp2_predicted_p)
rmse=np.sqrt(mean_squared_error(yp2_test,yp2_predicted_p))
nrmse= rmse/(maxd2['Power']-mind2['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 20052.22090578477
# R score: -0.2896529821364069
# Mean Absolute Error: 121.96587523254492
# Root Mean Absolute Error: 141.60586465886493
# Normalised Root Mean Absolute Error: 0    0.259351
# Name: Power, dtype: object

# %%
l=Lasso(alpha=0.1)
l.fit(xp2_train, yp2_train)
yp2_res = l.predict(xp2_test)
mse = mean_squared_error(yp2_test, yp2_res)
rp2 = r2_score(yp2_test, yp2_res)
mae = mean_absolute_error(yp2_test,yp2_res)
rmse=np.sqrt(mean_squared_error(yp2_test,yp2_res))
nrmse= rmse/(maxd2['Power']-mind2['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 600.1267339178454
# R score: 0.9614030168681387
# Mean Absolute Error: 18.597673687343086
# Root Mean Absolute Error: 24.497484236505702
# Normalised Root Mean Absolute Error: 0    0.044867
# Name: Power, dtype: object

# %%
ridge=Ridge(alpha=0.1)
ridge.fit(xp2_train, yp2_train)
yp2_res = ridge.predict(xp2_test)
mse = mean_squared_error(yp2_test, yp2_res)
rp2 = r2_score(yp2_test, yp2_res)
mae = mean_absolute_error(yp2_test,yp2_res)
rmse=np.sqrt(mean_squared_error(yp2_test,yp2_res))
nrmse= rmse/(maxd2['Power']-mind2['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 600.1286994945634
# R score: 0.9614028904526215
# Mean Absolute Error: 18.599981897006586
# Root Mean Absolute Error: 24.497524354402906
# Normalised Root Mean Absolute Error: 0    0.044867
# Name: Power, dtype: object

# %%
# Decision Tree
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(xp2_train, yp2_train)
yp2_predicted_d = regressor.predict(xp2_test)
mse = mean_squared_error(yp2_test, yp2_predicted_d)
rp2 = r2_score(yp2_test, yp2_predicted_d)
mae = mean_absolute_error(yp2_test,yp2_predicted_d)
rmse=np.sqrt(mean_squared_error(yp2_test,yp2_predicted_d))
nrmse= rmse/(maxd2['Power']-mind2['Power'])
print("Mean Squared Error:",mse)
print("R score:",rp2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 203.68062856890378
# R score: 0.9869003373106903
# Mean Absolute Error: 7.653696496253095
# Root Mean Absolute Error: 14.271672241503579
# Normalised Root Mean Absolute Error: 0    0.026139
# Name: Power, dtype: object

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=0, n_estimators=300)
rf.fit(xp2_train,yp2_train)
yp2_predicted_r = rf.predict(xp2_test)

mse = mean_squared_error(yp2_test, yp2_predicted_r)
rp2 = r2_score(yp2_test, yp2_predicted_r)
mae = mean_absolute_error(yp2_test,yp2_predicted_r)
rmse=np.sqrt(mean_squared_error(yp2_test,yp2_predicted_r))
nrmse= rmse/(maxd2['Power']-mind2['Power'])

print("Mean Squared Error:",mse)
print("R score:",rp2)
print("Mean Absolute Error:",mae)
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Mean Squared Error: 98.4002366860906
# R score: 0.9936714162844408
# Mean Absolute Error: 5.897370322048565
# Root Mean Absolute Error: 9.919689344233044
# Normalised Root Mean Absolute Error: 0    0.018168
# Name: Power, dtype: object

# %%
#XGBoost
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score
# fit model no training data
model = XGBRegressor()
model.fit(xp2_train, yp2_train)
# make predictions for test data
yp2_pred = model.predict(xp2_test)
predictions = [round(value) for value in yp2_pred]
rmse = np.sqrt(mean_squared_error(yp2_test, predictions))
nrmse= rmse/(maxd2['Power']-mind2['Power'])
print("Root Mean Absolute Error:",rmse)
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Root Mean Absolute Error: 12.926160787628733
# Normalised Root Mean Absolute Error: 0    0.023674
# Name: Power, dtype: object

# %%
#lgbm model   
import lightgbm as lgb
model = lgb.LGBMRegressor(learning_rate=0.01,max_depth=20,random_state=42)
model.fit(xp2_train,yp2_train,eval_set=[(xp2_test,yp2_test),(xp2_train,yp2_train)],
          verbose=20,eval_metric='logloss')
print('Training accuracy {:.4f} '.format(model.score(xp2_train,yp2_train)))
print('Testing accuracy {:.4f}'.format(model.score(xp2_test,yp2_test)))
yc2_pred = model.predict(xp2_test)
rmse = np.sqrt(mean_squared_error(yp2_test, yp2_pred))
nrmse= rmse/(maxd2['Power']-mind2['Power'])
print("MSE",mean_squared_error(yc2_test,yc2_pred))
print("RMSE",np.sqrt(mean_squared_error(yc2_test,yc2_pred)))
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# [20]	training's l2: 10542.7	valid_0's l2: 10527.6
# [40]	training's l2: 7172.24	valid_0's l2: 7161.4
# [60]	training's l2: 4910.55	valid_0's l2: 4902.59
# [80]	training's l2: 3390.56	valid_0's l2: 3384.75
# [100]	training's l2: 2368.87	valid_0's l2: 2364.67
# Training accuracy 0.8479
# Testing accuracy 0.8479
# MSE 276188.19262642117
# RMSE 525.5361002123652
# Normalised Root Mean Absolute Error: 0    0.023667
# Name: Power, dtype: object

# %%
# Neural Networks
import warnings
warnings.filterwarnings('ignore')
from keras.models import Sequential,model_from_json
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(10,)))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='relu'))
model.summary()
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model.fit(xp2_train,yp2_train,batch_size=100,epochs=10,verbose=1)
test=model.evaluate(xp2_test, yp2_test, verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 256)               2816
#
#  dense_11 (Dense)            (None, 256)               65792
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  dense_13 (Dense)            (None, 256)               65792
#
#  dense_14 (Dense)            (None, 1)                 257
#
# ...
# Total params: 200,449
# Trainable params: 200,449
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6729/6729 [==============================] - 20s 3ms/step - loss: 14278867.0000 - root_mean_squared_error: 3778.7388
# Epoch 2/10
# 6729/6729 [==============================] - 16s 2ms/step - loss: 311970.6562 - root_mean_squared_error: 558.5433
# Epoch 3/10
# ...

# %%
nrmse= 558.3878/(maxd2['Power']-mind2['Power'])
print("Normalised Root Mean Absolute Error:",nrmse)
# Out:
# Normalised Root Mean Absolute Error: 0    1.022688
# Name: Power, dtype: object
